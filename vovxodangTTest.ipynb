# %%
import json

# Define the file name
file_name = "vovxodang.json"

# Load the list of dictionaries from the JSON file
with open(file_name, 'r', encoding='utf-8') as json_file:
    loaded_data = json.load(json_file)

# Print the loaded data
print(len(loaded_data))
# Out:
# 42166

# %%
import json

# Define the file name
file_name = "data.json"

# Load the list of dictionaries from the JSON file
with open(file_name, 'r', encoding='utf-8') as json_file:
    data = json.load(json_file)

# Print the loaded data
print(len(data))
# Out:
# 209226

# %%
def get_AllMemberfromUrl(href, data):
    res = []
    for d in data:
        if d["href"] == href:#f'https://vov4.vov.vn{href}':
            res.append(d.copy())
    return res

# %%
import re

cleanedData = data.copy()
for d in cleanedData:
    if 'xodang' not in d.keys():
        continue
    text = d['xodang']
    
    phrases_to_remove = [
        "This is a modal window.", "Beginning of dialog window.", 
        "Escape will cancel and close the window.", "End of dialog window."
    ]
    
    for phrase in phrases_to_remove:
        text = text.replace(phrase, '')

  
    text = re.sub(r'https?://\S+', '', text)

    text = re.sub(r'\b[^ ]*/[^ ]*/[^ ]*/[^ ]*\b', '', text)

    text = text.replace('\t', ' ')
    text = re.sub(r' +', ' ', text)

 
    text = text.strip()


    d['xodang'] = text

# %%
import re

def clean_text(text):
    """
    Cleans a given text string by:
    - Removing unwanted phrases
    - Removing URLs
    - Removing words with 3 or more slashes (/)
    - Normalizing spaces and tabs

    Args:
        text (str): The input text string.

    Returns:
        str: The cleaned text.
    """
    if not isinstance(text, str):
        raise TypeError("Expected 'text' to be a string")

    phrases_to_remove = [
        "This is a modal window.", "Beginning of dialog window.", 
        "Escape will cancel and close the window.", "End of dialog window."
    ]

    for phrase in phrases_to_remove:
        text = text.replace(phrase, '')

    # Remove URLs
    text = re.sub(r'https?://\S+', '', text)

    # Remove words with 3 or more slashes
    text = re.sub(r'\b[^ ]*/[^ ]*/[^ ]*/[^ ]*\b', '', text)

    # Normalize spaces and tabs
    text = text.replace('\t', ' ')
    text = text.replace('\\', ' ')
    text = re.sub(r' +', ' ', text)

    # Trim leading or trailing spaces
    text = text.strip()

    return text

# %%
data = cleanedData

# %%
# Out:
# {'Tơdroăng': 52629, 'nếo': 119711, 'ai': 252514, 'pơlê': 399215, 'pơla': 96764, '(Thời': 23644, 'sự': 23716, 'xã': 23774, 'hội)': 23646, 'Pơxiâm': 1492, 'po': 57351, 'tơdroăng': 418301, 'pleăng': 9329, 'mơheăm': 14986, '‘’Hâi': 476, 't^ng': 5664, 'khêi’’': 55, 'roh': 35093, 'má': 65661, '12': 8065, '----------': 26112, 'VOV4': 36538, 'Sêdang': 43300, '-': 53194, 'Kơxo': 6393, 'lơ': 68627, '22/12': 76, 'a': 241733, 'Hà': 13814, 'Nội': 7469, 'pôa': 54831, 'Trương': 3182, 'Hòa': 4199, 'Bình': 8082, 'Ngế': 44347, 'pro': 239112, 'xiâm': 179981, 'pho\\': 12007, 'hnê': 170324, 'ngăn': 255499, 'Chin': 19665, 'phuh': 19938, 'Kăn': 53858, 'Vi': 26310, '[an': 15589, 'rak': 82288, 'tơniăn': 67051, 'troăng': 97259, 'prôk': 21740, '[a\\': 83277, 'rơxế': 14004, 'kơtâu': 8399, 'Tơnêi': 21072, 'têa': 216886, 'troh': 100226, 'veăng': 59418, 'leh': 14194, 'pơxiâm': 11308, '{a\\': 2982, 'ki': 520477, 'tơbleăng': 77843, 'tối': 144479, '‘’Pleăng': 70, 'kum': 83882, 'rêh': 54485, 'mơngế': 54013, 'êh': 527,
# ...

# %%
print(len(worddict.keys()))
# Out:
# 82256

# %%
import json
# Save list to a JSON file
with open("worddict.json", "w", encoding="utf-8") as file:
    json.dump(worddict, file, indent=4, ensure_ascii=False)

print(f"saved {len(worddict)}")
# Out:
# saved 82256

# %%
import re
worddict = {}

# Iterate through the list
for item in data:
    if "xodang" in item and "href" in item:
        text = item["xodang"]
        href = item["href"]

        # Remove sentence punctuation while keeping meaningful symbols intact
        cleaned_text = re.sub(r'[.,:!"“”]', ' ', text)
        cleaned_text = cleaned_text.replace('\n----------\n', '')
        words = cleaned_text.split()  # Split words properly

        for word in words:
            if word not in worddict:
                worddict[word] = {"count": 1, "hrefs": {href}}  # Use a set for unique hrefs
            else:
                worddict[word]["count"] += 1  # Increment count
                worddict[word]["hrefs"].add(href)  # Efficiently add href to the set

# Convert sets to lists for better JSON compatibility (if needed)
for word in worddict:
    worddict[word]["hrefs"] = list(worddict[word]["hrefs"])

print(worddict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 worddict = {}
#       4 # Iterate through the list
# ----> 5 for item in data:
#       6     if "xodang" in item and "href" in item:
#       7         text = item["xodang"]
#
# NameError: name 'data' is not defined

# %%
print(len(data))
print(len(cleanedData))
# Out:
# 209226
# 209226

# %%
import json
# Save list to a JSON file
with open("cleanedData.json", "w", encoding="utf-8") as file:
    json.dump(cleanedData, file, indent=4, ensure_ascii=False)

print(f"saved {len(cleanedData)}")
# Out:
# List saved to data.json successfully!

# %%
print(json.dumps(cleanedData, indent=4, ensure_ascii= False))

# %%
testing = [
    'https://vov4.vov.vn/xodang/todroang-neo-ai-pole-pola-thoi-su-xa-hoi/kan-xiam-hne-ngan-kuok-hoi-topui-ba-kan-hne-ngan-duma-kong-tea-kuok-hoi-rusi-432044.vov4',
    'https://vov4.vov.vn/xodang/todroang-neo-ai-pole-pola-thoi-su-xa-hoi/hop-topui-tono-na-kong-nge-koxo-make-in-viet-nam-a-gia-lai-467226.vov4',
    'https://vov4.vov.vn/xodang/todroang-neo-ai-pole-pola-thoi-su-xa-hoi/nge-pro-xiam-hne-ngan-hne-mohno-pei-pro-lem-tro-ma-moi-hnoang-cheang-gak-kring-cha-chan-poa-ho-chi-minh-kan-xiam-hne-ngan-tonei-tea-459900.vov4',
    'https://vov4.vov.vn/xodang/thon-pole-neo-nong-thon-moi/kopong-hdroang-kuan-ngo-a-cheam-loc-nam-mo-eam-sap-ing-koklea-kotie-426170.vov4',
    'https://vov4.vov.vn/xodang/todroang-neo-ai-pole-pola-thoi-su-xa-hoi/hak-ro-om-hyo-dak-lak-rono-oang-bro-tea-kodrua-481619.vov4'
]

# %%
import requests
import json
#model = 'gemini-2.0-pro-exp'
def generate_content(api_key, text_prompt, model):
    """
    Sends a POST request to the Gemini API to generate content.
    
    :param api_key: Your Gemini API key as a string.
    :param text_prompt: The text prompt for the AI to respond to.
    :return: The JSON response from the API.
    """
    url = f"https://generativelanguage.googleapis.com/v1beta/models/{model}:generateContent?key={api_key}"
    
    headers = {
        "Content-Type": "application/json"
    }

    data = {
        "contents": [
            {
                "parts": [
                    {
                        "text": text_prompt
                    }
                ]
            }
        ]
    }

    response = requests.post(url, headers=headers, data=json.dumps(data))

    if response.status_code == 200:
        return response.json()
    else:
        return f"Error: {response.status_code}, {response.text}"

apikey = 'AIzaSyDtHYoFJquuKbxIHlm1su8TJEhAVbFj7Rs'

# %%
import requests

def list_models(api_key):
    """
    Calls the Gemini API to retrieve the list of available models.

    :param api_key: Your Gemini API key as a string.
    :return: JSON response containing available models.
    """
    url = f"https://generativelanguage.googleapis.com/v1beta/models?key={api_key}"
    
    response = requests.get(url)

    if response.status_code == 200:
        return response.json()
    else:
        return f"Error: {response.status_code}, {response.text}"

# Example usage
api_key = "AIzaSyDtHYoFJquuKbxIHlm1su8TJEhAVbFj7Rs"
models = list_models(api_key)

# %%
print(json.dumps(models, indent=4, ensure_ascii= False))
# Out:
# {
#     "models": [
#         {
#             "name": "models/embedding-gecko-001",
#             "version": "001",
#             "displayName": "Embedding Gecko",
#             "description": "Obtain a distributed representation of a text.",
#             "inputTokenLimit": 1024,
#             "outputTokenLimit": 1,
#             "supportedGenerationMethods": [
#                 "embedText",
#                 "countTextTokens"
#             ]
#         },
#         {
#             "name": "models/gemini-1.0-pro-vision-latest",
#             "version": "001",
#             "displayName": "Gemini 1.0 Pro Vision",
#             "description": "The original Gemini 1.0 Pro Vision model version which was optimized for image understanding. Gemini 1.0 Pro Vision was deprecated on July 12, 2024. Move to a newer Gemini version.",
#             "inputTokenLimit": 12288,
#             "outputTokenLimit": 4096,
#             "supportedGenerationMethods": [
#                 "generateContent",
# ...

# %%
import json

# Load list from JSON file
with open("translatedData.json", "r", encoding="utf-8") as file:
    translatedData = json.load(file)

print(f"List loaded {len(translatedData)}")
# Out:
# List loaded 1588

# %%
prompt = 'translate this Xơ Đăng text into Vietnamese, just show the result, no extra explanation: \n VOV4.Xơ Đăng -  Tiô rơkong krếo thế dêi pôa Vương Đình Huệ - Kăn xiâm hnê ngăn Kuô̆k hô̆i, pôa Vyacheslav Victorovich Volodin, Kăn xiâm hnê ngăn Duma Kuô̆k hô̆i kong têa Rusi pơkuâ djâ Khu kăn xiâm kong têa Rusi lăm pôu Việt Nam sap hâi lơ 15 - 16/10.'
res = generate_content(apikey, prompt)

# %%
translatedData= []

# %%
visited = set()
for d in translatedData:
    visited.add(d['href'])
print(len(visited))
# Out:
# 0

# %%
tokenUsed = 0

# %%
import time
model = 'gemini-2.5-flash'
lim = 10
for link in loaded_data:
    if link in visited:
        continue
    linkdata = get_AllMemberfromUrl(link, data)
    for d in linkdata:
        if 'xodang' not in d.keys():
            continue
        if d['xodang'] and d['type'] != 'breadcrumb':
            #cleanText = d['xodang'].replace('//', '').replace('\n----------\n', '')
            #cleanText = d['xodang'].replace('This is a modal window.', '').replace('Beginning of dialog window.', '').replace('Escape will cancel and close the window.', '').replace('End of dialog window.', '')
            #cleanText=cleanText.replace('\t', ' ')
            cleanText = clean_text(d['xodang'])
            if cleanText.replace('/n', '').replace(' ', '') != '':
                prompt = f'translate this Xơ Đăng text into Vietnamese, just show the result, no extra explanation: {cleanText}'
                res = generate_content(apikey, prompt, model)
                
                d['vietnamese'] = res["candidates"][0]["content"]["parts"][0]["text"]
                
                tokenUsed += res["usageMetadata"]["totalTokenCount"]
            else:
                d['vietnamese'] = ''
        translatedData.append(d.copy())
        time.sleep(15)
    visited.add(link)
    if len(visited) >= lim:
        break
    print(len(visited))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[161], line 19
#      16     prompt = f'translate this Xơ Đăng text into Vietnamese, just show the result, no extra explanation: {cleanText}'
#      17     res = generate_content(apikey, prompt)
# ---> 19     d['vietnamese'] = res["candidates"][0]["content"]["parts"][0]["text"]
#      21     tokenUsed += res["usageMetadata"]["totalTokenCount"]
#      22 else:
#
# TypeError: string indices must be integers, not 'str'

# %%
print(res)
# Out:
# Error: 429, {
#   "error": {
#     "code": 429,
#     "message": "You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.",
#     "status": "RESOURCE_EXHAUSTED",
#     "details": [
#       {
#         "@type": "type.googleapis.com/google.rpc.QuotaFailure",
#         "violations": [
#           {
#             "quotaMetric": "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count",
#             "quotaId": "GenerateContentInputTokensPerModelPerMinute-FreeTier",
#             "quotaDimensions": {
#               "location": "global",
#               "model": "gemini-2.0-pro-exp"
#             }
#           },
#           {
#             "quotaMetric": "generativelanguage.googleapis.com/generate_content_free_tier_requests",
#             "quotaId": "GenerateRequestsPerDayPerProjectPerModel-FreeTier",
#             "quotaDimensions": {
# ...

# %%
print(len(translatedData))
# Out:
# 20

# %%
# Save list to a JSON file
with open(".json", "w", encoding="utf-8") as file:
    json.dump(translatedData, file, indent=4, ensure_ascii=False)

print("List saved to data.json successfully!")
# Out:
# List saved to data.json successfully!

# %%
print(tokenUsed)
# Out:
# 0
